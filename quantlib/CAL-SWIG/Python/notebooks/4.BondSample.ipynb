# %% [markdown]
# ## 1. 虚拟债券：以固定利率与到期收益率计算15年到期虚拟债券价格的时间序列

# %% [raw]
# 起息日    ：1999年12月20日
# 期限      ：15年
# 票息      ：0.06
# 到期收益率：0.05
# 付息频率  : 1年1次

# %%
from CAL.PyCAL import *
import pandas as pd

# %%
evaluationDate = pd.date_range('20000101', '20140325')

# %%
bondPrice = FixedRateBondEval(evaluationDate  = evaluationDate, 
                          startDate = pd.Timestamp('19991220'), 
                          tenor = 15, 
                          coupon = 0.06, 
                          ytm = 0.05, 
                          compounding = 0, 
                          frequency = 1, 
                          DayCounter = 1)
bondPrice['tradeDate'] = evaluationDate

# %%
bondPrice[:10]
# Out:
#    cleanPrice accruedAmount dirtyPrice macaulyDuration modifiedDuration  \
# 1    110.3563      0.230137   110.5864        10.50282         10.00269
# 2    110.3563      0.230137   110.5864        10.50282         10.00269
# 3    110.3563      0.230137   110.5864        10.50282         10.00269
# 4    110.3546     0.2465753   110.6012        10.50008         10.00008
# 5     110.353     0.2630137    110.616        10.49734          9.99747
# 6    110.3513     0.2794521   110.6308         10.4946         9.994861
# 7    110.3497     0.2958904   110.6456        10.49186         9.992252
# 8    110.3447     0.3452055   110.6899        10.48365         9.984424
# 9    110.3447     0.3452055   110.6899        10.48365         9.984424
# 10   110.3447     0.3452055   110.6899        10.48365         9.984424
#
#    convexity  tradeDate
# 1   132.8094 2000-01-01
# 2   132.8094 2000-01-02
# 3   132.8094 2000-01-03
# 4   132.7547 2000-01-04
# 5      132.7 2000-01-05
# 6   132.6454 2000-01-06
# 7   132.5907 2000-01-07
# 8   132.4269 2000-01-08
# 9   132.4269 2000-01-09
# 10  132.4269 2000-01-10
#
# [10 rows x 7 columns]

# %%
Plot(bondPrice, settings = {'x':'tradeDate', 'y': ['cleanPrice', 'dirtyPrice'],'title':u'万科债券虚拟价格 2010-2014'})

# %%
Plot(bondPrice, settings = {'x':'tradeDate', 'y': ['accruedAmount'],'title':u'万科债券虚拟应计利息 2010-2014'})

# %%
Plot(bondPrice, settings = {'x':'tradeDate', 'y': ['modifiedDuration','convexity'],'title':u'万科债券虚拟久期与凸性 2010-2014'})

# %% [markdown]
# ## 2. 固定利率债券收益率情景分析

# %%
ytm = np.linspace(0.0,0.8,81)

# %%
bondPrice = FixedRateBondEval(evaluationDate  = pd.Timestamp('20140310'), 
                          startDate = pd.Timestamp('19991220'), 
                          tenor = 15, 
                          coupon = 0.06, 
                          ytm = ytm, 
                          compounding = 0, 
                          frequency = 1, 
                          DayCounter = 1)
bondPrice['yield'] = ytm

# %%
bondPrice[25:35]
# Out:
#    cleanPrice accruedAmount dirtyPrice macaulyDuration modifiedDuration  \
# 26   87.73544      1.315068   89.05051       0.7808219        0.6246575
# 27   87.18311      1.315068   88.49818       0.7808219        0.6196999
# 28   86.63854      1.315068    87.9536       0.7808219        0.6148204
# 29   86.10154      1.315068   87.41661       0.7808219        0.6100171
# 30   85.57197      1.315068   86.88704       0.7808219        0.6052883
# 31   85.04966      1.315068   86.36473       0.7808219        0.6006322
# 32   84.53445      1.315068   85.84952       0.7808219        0.5960473
# 33    84.0262      1.315068   85.34127       0.7808219        0.5915318
# 34   83.52476      1.315068   84.83983       0.7808219        0.5870841
# 35   83.02999      1.315068   84.34506       0.7808219        0.5827029
#
#     convexity  yield
# 26  0.8899231   0.25
# 27  0.8758534   0.26
# 28  0.8621147   0.27
# 29  0.8486968   0.28
# 30  0.8355897   0.29
# 31  0.8227839   0.30
# 32  0.8102703   0.31
# 33  0.7980399   0.32
# 34  0.7860845   0.33
# 35  0.7743956   0.34
#
# [10 rows x 7 columns]

# %%
Plot(bondPrice, settings = {'x':'yield','y':['cleanPrice','dirtyPrice'],'title':u'万科债券收益率价格曲线 20140110','kind': 'Line'})

# %% [markdown]
# ### 2.1 使用久期对价格关于收益率的变化做一阶逼近

# %%
benchmarYield = 0.3
distance = bondPrice['yield'] - benchmarYield
bondPrice['distance'] = distance
benchmarkPrice = bondPrice[bondPrice['yield'] == benchmarYield]['cleanPrice'].values
P = bondPrice[bondPrice['yield'] == benchmarYield]['dirtyPrice'].values
benchmarkDuration = bondPrice[bondPrice['yield'] == benchmarYield]['modifiedDuration'].values
benchmarkConvexity = bondPrice[bondPrice['yield'] == benchmarYield]['convexity'].values
bondPrice['DurationAppr.'] =  - bondPrice['distance'] * benchmarkDuration * P + benchmarkPrice

# %%
Plot(bondPrice, settings = {'x':'yield','y':['cleanPrice','DurationAppr.'],'title':u'万科债券收益率价格曲线 久期逼近 20140110','kind': 'Line'})

# %% [markdown]
# ### 2.2 使用久期与凸性对价格关于收益率的变化做二阶逼近

# %%
bondPrice['DurationConvexityAppr.'] =  - bondPrice['distance'] * benchmarkDuration * P + + 0.5 * bondPrice['distance'] * bondPrice['distance'] * benchmarkConvexity * P + benchmarkPrice

# %%
Plot(bondPrice, settings = {'x':'yield','y':['cleanPrice','DurationConvexityAppr.'],'title':u'万科债券收益率价格曲线 久期凸性逼近 20140110','kind': 'Line'})

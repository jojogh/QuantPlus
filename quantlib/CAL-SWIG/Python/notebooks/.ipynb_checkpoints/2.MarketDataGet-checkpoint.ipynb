# %% [markdown]
# ## 1. 如何获取市场日线数据？使用MarketDataGet！

# %%
from CAL.PyCAL import *
import pandas as pd
defaultFigSize = (15,15)
defaultFontSize = 20

# %%
res =  MarketDataGetHistDailyQuotes(securityID = "000002.XSHE", 
                                    fields = ["shortNM", "closePrice"], 
                                    startDate = "20000106", 
                                    endDate = "20140110")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-3-11fbbc83e7e8> in <module>()
#       2                                     fields = ["closePrice"],
#       3                                     startDate = "20000106",
# ----> 4                                     endDate = "20140110")
#
# D:\Anaconda\lib\site-packages\CAL\DataAPI.pyc in MarketDataGetHistDailyQuotes(securityID, fields, startDate, endDate)
#      78
#      79     # try to read as bonds
# ---> 80     return BondDBUtilities.HistBondPrice(securityID, startDate, endDate, fields)
#      81
#      82
#
# D:\Anaconda\lib\site-packages\CAL\DBConnection.pyc in HistBondPrice(ticker, startDate, endDate, fields)
#     120         columns = ['tradeDate', 'ticker']
#     121
# --> 122         newFields = __uniqueFields__(fields, __availablePriceFields__)
#     123
#     124         for sqlField, fieldName in newFields:
#
# D:\Anaconda\lib\site-packages\CAL\DBConnection.pyc in __uniqueFields__(rawFields, avaDict)
#      72             newFields.add((avaDict[field.lower()][1], sqlFieldName))
#      73         except:
# ---> 74             raise Exception("#No field name available for " + field)
#      75
#      76     return newFields
#
# Exception: #No field name available for closePrice

# %%
Plot(res, settings = {'x':'tradeDate','y':'closePrice', 'title':u'万科历史收盘价格', 'figsize':defaultFigSize,
                      'fontsize':defaultFontSize})

# %%
closePrice = res['closePrice']
dailyReturn = closePrice[:-1].values / closePrice[1:] - 1
res['return'] = dailyReturn

# %%
res[:10]
# Out:
#        tradeDate  ticker exchangeCD shortNM  closePrice    return
# index
# 0     2000-01-06  000002       XSHE     万科Ａ       10.51       NaN
# 1     2000-01-07  000002       XSHE     万科Ａ       10.99 -0.043676
# 2     2000-01-10  000002       XSHE     万科Ａ       11.44 -0.039336
# 3     2000-01-11  000002       XSHE     万科Ａ       10.84  0.055351
# 4     2000-01-12  000002       XSHE     万科Ａ       10.46  0.036329
# 5     2000-01-13  000002       XSHE     万科Ａ       10.44  0.001916
# 6     2000-01-14  000002       XSHE     万科Ａ       10.03  0.040877
# 7     2000-01-17  000002       XSHE     万科Ａ       10.36 -0.031853
# 8     2000-01-18  000002       XSHE     万科Ａ       10.00  0.036000
# 9     2000-01-19  000002       XSHE     万科Ａ       10.10 -0.009901
#
# [10 rows x 6 columns]

# %%
Plot(res, settings = {'x':'closePrice', 'y':'return', 'kind':'Scatter', 'title':u'价格 vs. 收益率（散点图', 
                      'figsize':defaultFigSize, 'fontsize':defaultFontSize})

# %% [markdown]
# ## 2. 使用向量函数计算万科股票虚拟在值看涨期权

# %%
priceList = BSMPrice(optionType = 1, 
                     strike = res['closePrice'] + 1.0, 
                     spot = res['closePrice'], 
                     riskFree = 0.00, 
                     dividend = 0.00, 
                     volatility = 0.25, 
                     maturity = 2.0)
priceList['strike'] = res['closePrice'] + 1.0
priceList['stockPrice'] = res['closePrice']

# %%
priceList[:10]
# Out:
#           price      delta       gamma      vega  strike  stockPrice
# index
# 0       1.09508  0.4680008   0.1070169  5.910548   11.51       10.51
# 1      1.160354  0.4722787   0.1024253  6.185468   11.99       10.99
# 2      1.221699  0.4759788  0.09845569  6.442625   12.44       11.44
# 3      1.139938  0.4709804   0.1038185  6.099628   11.84       10.84
# 4      1.088291  0.4675338   0.1075182   5.88187   11.46       10.46
# 5      1.085576  0.4673458     0.10772  5.870397   11.44       10.44
# 6      1.029993  0.4633363    0.112025  5.634907   11.03       10.03
# 7      1.074719   0.466587   0.1085347  5.824492   11.36       10.36
# 8      1.025931  0.4630307   0.1123531  5.617654   11.00       10.00
# 9      1.039472  0.4640426   0.1112666  5.675153   11.10       10.10
#
# [10 rows x 6 columns]

# %%
Plot(priceList, settings = {'y':['price'], "title":u"万科期权价格 2010~2014", 'figsize':defaultFigSize, 
                            'fontsize':defaultFontSize})

# %% [markdown]
# ## 3. 获取财报数据？使用FundamentalBalanceSheetRange

# %%
res = FundamentalBalanceSheetRange(securityID = '600110',
                                   startDate = '20050101',
                                   endDate = '20140101',
                                   reportType = 'Q')

# %%
res[:10]
# Out:
#           ticker exchangeCD PUBLISH_DATE    END_DATE  YEAR REPORT_TYPE  \
# index
# 0     2060-01-10       XSHG   2007-04-24  2007-03-31  2007          Q1
# 1     2060-01-10       XSHG   2007-10-26  2007-09-30  2007          Q3
# 2     2060-01-10       XSHG   2008-04-22  2008-03-31  2008          Q1
# 3     2060-01-10       XSHG   2008-10-28  2008-09-30  2008          Q3
# 4     2060-01-10       XSHG   2009-04-29  2009-03-31  2009          Q1
# 5     2060-01-10       XSHG   2009-10-20  2009-09-30  2009          Q3
# 6     2060-01-10       XSHG   2010-04-27  2010-03-31  2010          Q1
# 7     2060-01-10       XSHG   2010-10-30  2010-09-30  2010          Q3
# 8     2060-01-10       XSHG   2011-04-26  2011-03-31  2011          Q1
# 9     2060-01-10       XSHG   2011-10-27  2011-09-30  2011          Q3
#
#       MERGED_FLAG ADJUSTED_FLAG INDUSTRY_CATEGORY  CASH_AND_CASH_EQUIV  \
# index
# 0            合并公司          期末余额             一般工商业         7.783533e+07
# 1            合并公司          期末余额             一般工商业         4.486031e+08
# 2            合并公司          期末余额             一般工商业         4.659522e+08
# 3            合并公司          期末余额             一般工商业         5.734012e+08
# 4            合并公司          期末余额             一般工商业         6.166655e+08
# 5            合并公司          期末余额             一般工商业         3.929818e+08
# 6            合并公司          期末余额             一般工商业         5.335936e+08
# 7            合并公司          期末余额             一般工商业         9.210604e+08
# 8            合并公司          期末余额             一般工商业         8.185389e+08
# 9            合并公司          期末余额             一般工商业         4.124411e+08
#
#        NOTES_RECEIV  ACCOUNT_RECEIV    PREPAYMENT  INT_RECEIV  DIV_RECEIV  \
# index
# 0      3.561229e+07    1.394793e+08  4.249594e+07         NaN         NaN
# 1      2.794802e+07    1.538614e+08  1.139621e+08         NaN         NaN
# 2      4.086500e+07    1.719693e+08  4.783874e+08         NaN         NaN
# 3      4.238717e+07    2.283032e+08  2.369453e+08         NaN         NaN
# 4      4.461670e+07    1.427284e+08  8.336928e+08         NaN         NaN
# 5      5.651328e+07    1.962594e+08  9.036766e+08         NaN         NaN
# 6      5.325153e+07    1.962170e+08  7.250395e+08         NaN         NaN
# 7      9.850329e+07    2.065861e+08  9.155759e+08         NaN         NaN
# 8      5.331982e+07    3.256753e+08  1.200881e+09         NaN         NaN
# 9      1.088959e+08    4.257888e+08  8.119736e+08         NaN         NaN
#
#         OTH_RECEIV   INVENTORIES  NCA_WITHIN_1Y     OTH_CA      TOTAL_CA
# index
# 0      66815576.12  1.477039e+08            NaN  174916.83  5.101172e+08 ...
# 1      59826917.90  1.562259e+08            NaN   96893.97  9.605243e+08 ...
# 2      59659658.84  2.098815e+08       37142.57        NaN  1.426752e+09 ...
# 3      56624881.46  1.729496e+08            NaN        NaN  1.310611e+09 ...
# 4      25302532.32  1.715630e+08      122541.62        NaN  1.834692e+09 ...
# 5      39009511.19  1.881378e+08      534034.89        NaN  1.777112e+09 ...
# 6      37819218.13  1.923771e+08            NaN        NaN  1.738298e+09 ...
# 7      31826483.58  2.273711e+08            NaN        NaN  2.400923e+09 ...
# 8      46532825.48  4.330794e+08            NaN        NaN  2.878028e+09 ...
# 9      34613739.50  4.509822e+08            NaN        NaN  2.244695e+09 ...
#
# [10 rows x 64 columns]

# %%
Plot(res, settings= {'x':u'END_DATE', 'y':[u'TOTAL_ASSETS',u'TOTAL_LIAB', u'TOTAL_EQUITY'], 
                     'kind':'Bar', 'title':u'浦发银行2007~2013季度报表', 'figsize':defaultFigSize,
                     'fontsize':defaultFontSize})

# %% [markdown]
# ## 4. 获取股票分类静态数据

# %%
res = SecurityCategory(standard = 'SW', level = 1)

# %%
countDF = res.groupby('industryName')

# %%
res[:10]
# Out:
#        ticker shortNM  industryCode industryName
# index
# 0      000001    平安银行        440000         金融服务
# 1      000002     万科Ａ        430000          房地产
# 2      400016    金田Ａ３        510000           综合
# 3      000004    国农科技        370000         医药生物
# 4      000005    世纪星源        430000          房地产
# 5      000006    深振业Ａ        430000          房地产
# 6      000007    零七股份        510000           综合
# 7      000008     宝利来        510000           综合
# 8      000009    中国宝安        430000          房地产
# 9      000010     深华新        510000           综合
#
# [10 rows x 4 columns]

# %%
ticker = pd.DataFrame(countDF['ticker'].count())

# %%
ticker.columns = ['No. of Corp.']
ticker[:10]
# Out:
#               No. of Corp.
# industryName
# 交运设备                   131
# 交通运输                    93
# 信息服务                   153
# 信息设备                    95
# 公用事业                    91
# 农林牧渔                    88
# 化工                     252
# 医药生物                   184
# 商业贸易                    96
# 家用电器                    53
#
# [10 rows x 1 columns]

# %%
Plot(ticker, settings = {'x':'No. of Corp.', 'kind':'Pie','title':u'申万一级行业分类统计', 
                         'figsize':defaultFigSize,
                         'fontsize':defaultFontSize})

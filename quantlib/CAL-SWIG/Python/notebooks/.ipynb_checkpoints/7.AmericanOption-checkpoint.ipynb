# %% [markdown]
# 美式期权定价逼近公式
# -----------------
# BaroneAdesi-Whaley 美式期权逼近公式
#
# Barone-Adesi, G.; R. Whaley (1987). Efficient Analytic Approximation of American Option Values. Journal of Derivatives 42 (2): 301–320

# %%
from CAL.PyCAL import *
import numpy as np
import pandas as pd

# %% [markdown]
# 1. 美式看涨期权
# -------------
# 随着红利率的上升，美式期权与欧式期权的价差增大。在红利率为0时，美式期权等于欧式期权。

# %%
optionType = 1
strike = 105.0
spot = 100.0
riskFree = 0.05 
dividend = np.linspace(0.0, 0.10,101)
volatility = 0.25
maturity = 5.0

europeanPrice = BSMPrice(optionType = optionType,
strike = strike, 
spot = spot, 
riskFree = riskFree, 
dividend = dividend,
volatility = volatility,
maturity = maturity)

americanPrice= BaroneAdesiWhaleyPrice(optionType = optionType,
strike = strike, 
spot = spot, 
riskFree = riskFree, 
dividend = dividend,
volatility = volatility,
maturity = maturity)

comparingDF = pd.DataFrame({'dividend':dividend, 'European':europeanPrice['price'].values, 'American':americanPrice['price'].values})

# %%
Plot(comparingDF, settings = {'x':'dividend', 'y':['European', 'American'],  'xlim':(0.0,0.1), 'title':u'看涨期权欧式与美式比较'})

# %% [markdown]
# 1. 美式看跌期权
# -------------
# 随着无风险利率的上升，美式期权与欧式期权的价差增大。在无风险率为0时，美式期权等于欧式期权。

# %%
optionType = -1
strike = 105.0
spot = 100.0
riskFree = np.linspace(0.0, 0.10,101) 
dividend = 0.05
volatility = 0.25
maturity = 5.0

europeanPrice = BSMPrice(optionType = optionType,
strike = strike, 
spot = spot, 
riskFree = riskFree, 
dividend = dividend,
volatility = volatility,
maturity = maturity)

americanPrice= BaroneAdesiWhaleyPrice(optionType = optionType,
strike = strike, 
spot = spot, 
riskFree = riskFree, 
dividend = dividend,
volatility = volatility,
maturity = maturity)

comparingDF = pd.DataFrame({'riskFree':riskFree, 'European':europeanPrice['price'].values, 'American':americanPrice['price'].values})

# %%
Plot(comparingDF, settings = {'x':'riskFree', 'y':['European', 'American'], 'xlim':(0.0,0.1), 'title':u'看涨期权欧式与美式比较'})

# %%
americanPrice
# Out:
#        price      delta        gamma      vega
# 1    30.3653  0.7387328  0.005816961  72.71201
# 2   29.99799  0.7321561  0.005821056  72.77061
# 3   29.63523  0.7256412  0.005825132  72.84468
# 4   29.27728  0.7191957  0.005829311  72.93404
# 5   28.92428  0.7128238  0.005833671  73.03755
# 6   28.57629  0.7065286  0.005838271  73.15397
# 7   28.23334   0.700312  0.005843164  73.28215
# 8   27.89546  0.6941759  0.005848394  73.42098
# 9   27.56265   0.688122  0.005854009  73.56947
# 10  27.23492  0.6821515  0.005860051  73.72667
# 11  26.91227  0.6762659  0.005866565  73.89165
# 12  26.59469  0.6704664  0.005873596  74.06349
# 13  26.28217  0.6647542  0.005881186  74.24123
